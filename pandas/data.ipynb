# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('industry.csv')

# %%
data.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2023                     Level 1                99999       All industries
# 1  2023                     Level 1                99999       All industries
# 2  2023                     Level 1                99999       All industries
# 3  2023                     Level 1                99999       All industries
# 4  2023                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
data.tail()
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50980  2013                     Level 3                 ZZ11
# 50981  2013                     Level 3                 ZZ11
# 50982  2013                     Level 3                 ZZ11
# 50983  2013                     Level 3                 ZZ11
# 50984  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC       Units Variable_code  \
# 50980  Food product manufacturing  Percentage           H37
# 50981  Food product manufacturing  Percentage           H38
# 50982  Food product manufacturing  Percentage           H39
# 50983  Food product manufacturing  Percentage           H40
# 50984  Food product manufacturing  Percentage           H41
#
#                              Variable_name Variable_category Value  \
# 50980                          Quick ratio  Financial ratios    52
# 50981  Margin on sales of goods for resale  Financial ratios    40
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50985 entries, 0 to 50984
# Data columns (total 10 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Year                         50985 non-null  int64
#  1   Industry_aggregation_NZSIOC  50985 non-null  object
#  2   Industry_code_NZSIOC         50985 non-null  object
#  3   Industry_name_NZSIOC         50985 non-null  object
#  4   Units                        50985 non-null  object
#  5   Variable_code                50985 non-null  object
#  6   Variable_name                50985 non-null  object
#  7   Variable_category            50985 non-null  object
#  8   Value                        50985 non-null  object
#  9   Industry_code_ANZSIC06       50985 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 3.9+ MB

# %%
data.describe()
# Out:
#                Year
# count  50985.000000
# mean    2018.000000
# std        3.162309
# min     2013.000000
# 25%     2015.000000
# 50%     2018.000000
# 75%     2021.000000
# max     2023.000000

# %%
compute=data[['Year','Industry_name_NZSIOC','Value']].head(15)

# %%
compute
# Out:
#     Year Industry_name_NZSIOC   Value
# 0   2023       All industries  930995
# 1   2023       All industries  821630
# 2   2023       All industries   84354
# 3   2023       All industries   25010
# 4   2023       All industries  832964
# 5   2023       All industries   55267
# 6   2023       All industries    7426
# 7   2023       All industries   30814
# 8   2023       All industries  147663
# 9   2023       All industries     269
# 10  2023       All industries    1639
# 11  2023       All industries  566979
# 12  2023       All industries   23176
# 13  2023       All industries   80778
# 14  2023       All industries   88197

# %%
data['Value'].value_counts().tail().plot(kind='bar')
# Out:
# <Axes: xlabel='Value'>

# %%
def company():
     filtered_data = data[data['Industry_name_NZSIOC'] == 'Food product manufacturing']
     if not filtered_data.empty:
          filtered_data['Value'].value_counts().head(8).plot.pie(autopct='%.1f%%') 
          plt.show()
     else:
           print("empty:")

# %%
company()

# %%
 food=data[data['Industry_name_NZSIOC']== 'Food product manufacturing']

# %%
food
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50949  2013                     Level 3                 ZZ11
# 50950  2013                     Level 3                 ZZ11
# 50951  2013                     Level 3                 ZZ11
# 50952  2013                     Level 3                 ZZ11
# 50953  2013                     Level 3                 ZZ11
# 50954  2013                     Level 3                 ZZ11
# 50955  2013                     Level 3                 ZZ11
# 50956  2013                     Level 3                 ZZ11
# 50957  2013                     Level 3                 ZZ11
# 50958  2013                     Level 3                 ZZ11
# 50959  2013                     Level 3                 ZZ11
# 50960  2013                     Level 3                 ZZ11
# 50961  2013                     Level 3                 ZZ11
# 50962  2013                     Level 3                 ZZ11
# ...

# %%
food.count
# Out:
# <bound method DataFrame.count of        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50949  2013                     Level 3                 ZZ11
# 50950  2013                     Level 3                 ZZ11
# 50951  2013                     Level 3                 ZZ11
# 50952  2013                     Level 3                 ZZ11
# 50953  2013                     Level 3                 ZZ11
# 50954  2013                     Level 3                 ZZ11
# 50955  2013                     Level 3                 ZZ11
# 50956  2013                     Level 3                 ZZ11
# 50957  2013                     Level 3                 ZZ11
# 50958  2013                     Level 3                 ZZ11
# 50959  2013                     Level 3                 ZZ11
# 50960  2013                     Level 3                 ZZ11
# 50961  2013                     Level 3                 ZZ11
# 50962  2013                     Level 3                 ZZ11
# ...

# %%
food.shape
foods=food.head(8)

# %%
import seaborn as sns

# %%
sns.lineplot(x="Value",y="Variable_name",data=foods)
# Out:
# <Axes: xlabel='Value', ylabel='Variable_name'>

# %%
foods.info
# Out:
# <bound method DataFrame.info of        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 50949  2013                     Level 3                 ZZ11
# 50950  2013                     Level 3                 ZZ11
# 50951  2013                     Level 3                 ZZ11
# 50952  2013                     Level 3                 ZZ11
# 50953  2013                     Level 3                 ZZ11
# 50954  2013                     Level 3                 ZZ11
# 50955  2013                     Level 3                 ZZ11
# 50956  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 50949  Food product manufacturing  Dollars (millions)           H01
# 50950  Food product manufacturing  Dollars (millions)           H02
# 50951  Food product manufacturing  Dollars (millions)           H03
# 50952  Food product manufacturing  Dollars (millions)           H05
# ...

# %%
foods.describe()
# Out:
#          Year
# count     8.0
# mean   2013.0
# std       0.0
# min    2013.0
# 25%    2013.0
# 50%    2013.0
# 75%    2013.0
# max    2013.0
